# %%
import lightkurve as lk
import matplotlib.pyplot as plt
import pandas as pd

# %%
tic = '39174351'

search = lk.search_lightcurve(f'TIC {tic}', author='SPOC', exptime=120)
search
# Out:
# SearchResult containing 2 data products.
#
#  #     mission     year author exptime target_name distance
#                                   s                 arcsec
# --- -------------- ---- ------ ------- ----------- --------
#   0 TESS Sector 22 2020   SPOC     120    39174351      0.0
#   1 TESS Sector 49 2022   SPOC     120    39174351      0.0

# %%
lc = search[0].download(quality_bitmask='hard').normalize().remove_outliers(sigma=3.5)

fig, ax = plt.subplots(figsize=(8,4))
lc.plot(ax=ax, linewidth=0, marker='o', color='k', markersize=1)
plt.show()

# %%
pg = lc.to_periodogram(maximum_frequency=10)
pg.plot()
# Out:
# <Axes: xlabel='Frequency [$\\mathrm{\\frac{1}{d}}$]', ylabel='Power'>

# %%
len(pg.frequency)
# Out:
# 1314

# %%
sorted(pg.power, reverse=True)
# Out:
# [<Quantity 0.06540981>,
#  <Quantity 0.06394423>,
#  <Quantity 0.05751307>,
#  <Quantity 0.05349776>,
#  <Quantity 0.04199376>,
#  <Quantity 0.03640167>,
#  <Quantity 0.02338918>,
#  <Quantity 0.02262162>,
#  <Quantity 0.02255131>,
#  <Quantity 0.02239039>,
#  <Quantity 0.02148411>,
#  <Quantity 0.01941756>,
#  <Quantity 0.01727653>,
#  <Quantity 0.0164485>,
#  <Quantity 0.01580655>,
#  <Quantity 0.01312273>,
#  <Quantity 0.01267958>,
#  <Quantity 0.01250208>,
#  <Quantity 0.01236916>,
#  <Quantity 0.01217105>,
#  <Quantity 0.01194971>,
#  <Quantity 0.01170384>,
#  <Quantity 0.01050961>,
#  <Quantity 0.00965314>,
#  <Quantity 0.00951501>,
#  <Quantity 0.00845689>,
#  <Quantity 0.00844323>,
#  <Quantity 0.00779789>,
#  <Quantity 0.00765108>,
#  <Quantity 0.00739465>,
#  <Quantity 0.00716808>,
#  <Quantity 0.00694281>,
#  <Quantity 0.00687701>,
#  <Quantity 0.00686363>,
#  <Quantity 0.00660917>,
#  <Quantity 0.00641644>,
#  <Quantity 0.00612651>,
#  <Quantity 0.00572305>,
#  <Quantity 0.00540921>,
#  <Quantity 0.00534765>,
#  <Quantity 0.00517627>,
#  <Quantity 0.00502214>,
#  <Quantity 0.00482293>,
#  <Quantity 0.00477443>,
#  <Quantity 0.00457371>,
#  <Quantity 0.00452335>,
#  <Quantity 0.00451436>,
#  <Quantity 0.00443669>,
#  <Quantity 0.00431965>,
#  <Quantity 0.00425023>,
#  <Quantity 0.00410826>,
#  <Quantity 0.00375177>,
#  <Quantity 0.00367971>,
#  <Quantity 0.00365738>,
#  <Quantity 0.00363385>,
#  <Quantity 0.00361676>,
#  <Quantity 0.00352396>,
#  <Quantity 0.00349584>,
#  <Quantity 0.00347983>,
#  <Quantity 0.00345053>,
#  <Quantity 0.00336956>,
#  <Quantity 0.00334338>,
#  <Quantity 0.00332095>,
#  <Quantity 0.00313142>,
#  <Quantity 0.00312345>,
#  <Quantity 0.00309875>,
#  <Quantity 0.00309588>,
#  <Quantity 0.0030891>,
#  <Quantity 0.0030434>,
#  <Quantity 0.00300044>,
#  <Quantity 0.00287219>,
#  <Quantity 0.00285618>,
#  <Quantity 0.00276679>,
#  <Quantity 0.00268983>,
#  <Quantity 0.00267483>,
#  <Quantity 0.00264393>,
#  <Quantity 0.00262177>,
#  <Quantity 0.00261571>,
#  <Quantity 0.00261552>,
#  <Quantity 0.00260081>,
#  <Quantity 0.00258295>,
#  <Quantity 0.0025809>,
#  <Quantity 0.00256566>,
#  <Quantity 0.00255982>,
#  <Quantity 0.00255595>,
#  <Quantity 0.00255283>,
#  <Quantity 0.00254232>,
#  <Quantity 0.00253371>,
#  <Quantity 0.00252731>,
#  <Quantity 0.00251782>,
#  <Quantity 0.00248387>,
#  <Quantity 0.00246628>,
#  <Quantity 0.0024564>,
#  <Quantity 0.00244725>,
#  <Quantity 0.00243712>,
#  <Quantity 0.0024255>,
#  <Quantity 0.00241614>,
#  <Quantity 0.00239187>,
#  <Quantity 0.00237852>,
#  <Quantity 0.00237347>,
#  <Quantity 0.00236591>,
#  <Quantity 0.00236116>,
#  <Quantity 0.00234294>,
#  <Quantity 0.00234117>,
#  <Quantity 0.00233837>,
#  <Quantity 0.00233013>,
#  <Quantity 0.00232091>,
#  <Quantity 0.00231679>,
#  <Quantity 0.00229019>,
#  <Quantity 0.00227164>,
#  <Quantity 0.00226214>,
#  <Quantity 0.00225297>,
#  <Quantity 0.00224723>,
#  <Quantity 0.00224207>,
#  <Quantity 0.00223998>,
#  <Quantity 0.00221868>,
#  <Quantity 0.00221464>,
#  <Quantity 0.0021767>,
#  <Quantity 0.00216498>,
#  <Quantity 0.00215777>,
#  <Quantity 0.00215331>,
#  <Quantity 0.0021495>,
#  <Quantity 0.00214583>,
#  <Quantity 0.00213234>,
#  <Quantity 0.00211505>,
#  <Quantity 0.00209492>,
#  <Quantity 0.00209317>,
#  <Quantity 0.00208275>,
#  <Quantity 0.00207881>,
#  <Quantity 0.00206957>,
#  <Quantity 0.00206487>,
#  <Quantity 0.00206186>,
#  <Quantity 0.0020519>,
#  <Quantity 0.0020474>,
#  <Quantity 0.00203484>,
#  <Quantity 0.00202689>,
#  <Quantity 0.00200842>,
#  <Quantity 0.00200081>,
#  <Quantity 0.00198774>,
#  <Quantity 0.00198402>,
#  <Quantity 0.00198009>,
#  <Quantity 0.00197083>,
#  <Quantity 0.0019636>,
#  <Quantity 0.00195669>,
#  <Quantity 0.00195385>,
#  <Quantity 0.00195274>,
#  <Quantity 0.00195131>,
#  <Quantity 0.00194376>,
#  <Quantity 0.00193703>,
#  <Quantity 0.00192817>,
#  <Quantity 0.00190979>,
#  <Quantity 0.00190153>,
#  <Quantity 0.00189584>,
#  <Quantity 0.00186835>,
#  <Quantity 0.00186113>,
#  <Quantity 0.00184871>,
#  <Quantity 0.0018483>,
#  <Quantity 0.00184598>,
#  <Quantity 0.00184031>,
#  <Quantity 0.00183885>,
#  <Quantity 0.00183716>,
#  <Quantity 0.00182927>,
#  <Quantity 0.00180723>,
#  <Quantity 0.00176945>,
#  <Quantity 0.00175867>,
#  <Quantity 0.00171051>,
#  <Quantity 0.00170897>,
#  <Quantity 0.00169782>,
#  <Quantity 0.00167568>,
#  <Quantity 0.00166399>,
#  <Quantity 0.00164398>,
#  <Quantity 0.0016421>,
#  <Quantity 0.0016218>,
#  <Quantity 0.00161326>,
#  <Quantity 0.00161122>,
#  <Quantity 0.00159992>,
#  <Quantity 0.00159266>,
#  <Quantity 0.00158263>,
#  <Quantity 0.00157391>,
#  <Quantity 0.00156785>,
#  <Quantity 0.00156736>,
#  <Quantity 0.00155518>,
#  <Quantity 0.00155326>,
#  <Quantity 0.00155221>,
#  <Quantity 0.00153775>,
#  <Quantity 0.00152382>,
#  <Quantity 0.00150145>,
#  <Quantity 0.0014995>,
#  <Quantity 0.00148962>,
#  <Quantity 0.00148445>,
#  <Quantity 0.00146837>,
#  <Quantity 0.00146531>,
#  <Quantity 0.00146418>,
#  <Quantity 0.00145765>,
#  <Quantity 0.00145707>,
#  <Quantity 0.00144223>,
#  <Quantity 0.00143661>,
#  <Quantity 0.00143618>,
#  <Quantity 0.00143235>,
#  <Quantity 0.0014277>,
#  <Quantity 0.00142671>,
#  <Quantity 0.00142202>,
#  <Quantity 0.00140366>,
#  <Quantity 0.00139729>,
#  <Quantity 0.00139675>,
#  <Quantity 0.00139638>,
#  <Quantity 0.00139422>,
#  <Quantity 0.00139245>,
#  <Quantity 0.00139228>,
#  <Quantity 0.00139144>,
#  <Quantity 0.00138619>,
#  <Quantity 0.00137492>,
#  <Quantity 0.00136949>,
#  <Quantity 0.00136483>,
#  <Quantity 0.00136431>,
#  <Quantity 0.00136>,
#  <Quantity 0.00132764>,
#  <Quantity 0.0013245>,
#  <Quantity 0.00132354>,
#  <Quantity 0.00131973>,
#  <Quantity 0.00131574>,
#  <Quantity 0.00131176>,
#  <Quantity 0.00130035>,
#  <Quantity 0.00129591>,
#  <Quantity 0.00129563>,
#  <Quantity 0.00128534>,
#  <Quantity 0.00128481>,
#  <Quantity 0.0012838>,
#  <Quantity 0.00128271>,
#  <Quantity 0.00128246>,
#  <Quantity 0.00127756>,
#  <Quantity 0.00127421>,
#  <Quantity 0.0012592>,
#  <Quantity 0.00125733>,
#  <Quantity 0.0012486>,
#  <Quantity 0.0012478>,
#  <Quantity 0.00124533>,
#  <Quantity 0.00124114>,
#  <Quantity 0.00123844>,
#  <Quantity 0.0012384>,
#  <Quantity 0.00123202>,
#  <Quantity 0.00123046>,
#  <Quantity 0.00122275>,
#  <Quantity 0.00122229>,
#  <Quantity 0.00121924>,
#  <Quantity 0.00121796>,
#  <Quantity 0.00121739>,
#  <Quantity 0.00121504>,
#  <Quantity 0.00121478>,
#  <Quantity 0.00121057>,
#  <Quantity 0.00120964>,
#  <Quantity 0.00120835>,
#  <Quantity 0.00120519>,
#  <Quantity 0.00119541>,
#  <Quantity 0.00119167>,
#  <Quantity 0.00119156>,
#  <Quantity 0.00119073>,
#  <Quantity 0.00118725>,
#  <Quantity 0.00118665>,
#  <Quantity 0.00118118>,
#  <Quantity 0.00117763>,
#  <Quantity 0.0011738>,
#  <Quantity 0.00117075>,
#  <Quantity 0.0011686>,
#  <Quantity 0.00116601>,
#  <Quantity 0.00116472>,
#  <Quantity 0.00116293>,
#  <Quantity 0.00116141>,
#  <Quantity 0.00115543>,
#  <Quantity 0.00113918>,
#  <Quantity 0.00112717>,
#  <Quantity 0.00112598>,
#  <Quantity 0.00112465>,
#  <Quantity 0.00112402>,
#  <Quantity 0.00112011>,
#  <Quantity 0.00111242>,
#  <Quantity 0.0011116>,
#  <Quantity 0.00110979>,
#  <Quantity 0.00110906>,
#  <Quantity 0.00110559>,
#  <Quantity 0.00109889>,
#  <Quantity 0.0010873>,
#  <Quantity 0.00108702>,
#  <Quantity 0.00108494>,
#  <Quantity 0.00108348>,
#  <Quantity 0.0010819>,
#  <Quantity 0.00107968>,
#  <Quantity 0.00107827>,
#  <Quantity 0.00107153>,
#  <Quantity 0.00106713>,
#  <Quantity 0.00106451>,
#  <Quantity 0.00106193>,
#  <Quantity 0.00106148>,
#  <Quantity 0.00105985>,
#  <Quantity 0.00105804>,
#  <Quantity 0.00104078>,
#  <Quantity 0.00103559>,
#  <Quantity 0.00103335>,
#  <Quantity 0.00103313>,
#  <Quantity 0.00102507>,
#  <Quantity 0.00102192>,
#  <Quantity 0.00101575>,
#  <Quantity 0.00101524>,
#  <Quantity 0.00101499>,
#  <Quantity 0.00101055>,
#  <Quantity 0.00100863>,
#  <Quantity 0.00100664>,
#  <Quantity 0.00100547>,
#  <Quantity 0.00100011>,
#  <Quantity 0.00099693>,
#  <Quantity 0.00098668>,
#  <Quantity 0.00098354>,
#  <Quantity 0.00098117>,
#  <Quantity 0.00098034>,
#  <Quantity 0.00097981>,
#  <Quantity 0.00096155>,
#  <Quantity 0.00095843>,
#  <Quantity 0.00095545>,
#  <Quantity 0.00095334>,
#  <Quantity 0.00094773>,
#  <Quantity 0.0009471>,
#  <Quantity 0.0009451>,
#  <Quantity 0.00093877>,
#  <Quantity 0.00093791>,
#  <Quantity 0.00093693>,
#  <Quantity 0.00093425>,
#  <Quantity 0.00093063>,
#  <Quantity 0.00092973>,
#  <Quantity 0.00092823>,
#  <Quantity 0.00092553>,
#  <Quantity 0.00092436>,
#  <Quantity 0.00092077>,
#  <Quantity 0.00092052>,
#  <Quantity 0.00091899>,
#  <Quantity 0.00091462>,
#  <Quantity 0.00090781>,
#  <Quantity 0.00090521>,
#  <Quantity 0.00089732>,
#  <Quantity 0.000892>,
#  <Quantity 0.00089031>,
#  <Quantity 0.00088452>,
#  <Quantity 0.00087792>,
#  <Quantity 0.00087687>,
#  <Quantity 0.00087667>,
#  <Quantity 0.00087341>,
#  <Quantity 0.00087291>,
#  <Quantity 0.00086768>,
#  <Quantity 0.00086657>,
#  <Quantity 0.00086223>,
#  <Quantity 0.00085801>,
#  <Quantity 0.00085745>,
#  <Quantity 0.00085428>,
#  <Quantity 0.00085117>,
#  <Quantity 0.00085101>,
#  <Quantity 0.00084792>,
#  <Quantity 0.00084612>,
#  <Quantity 0.00084279>,
#  <Quantity 0.0008419>,
#  <Quantity 0.00084149>,
#  <Quantity 0.00084064>,
#  <Quantity 0.00083982>,
#  <Quantity 0.00083886>,
#  <Quantity 0.0008387>,
#  <Quantity 0.00083746>,
#  <Quantity 0.00083533>,
#  <Quantity 0.0008315>,
#  <Quantity 0.00082877>,
#  <Quantity 0.00082561>,
#  <Quantity 0.00081492>,
#  <Quantity 0.00081345>,
#  <Quantity 0.00081336>,
#  <Quantity 0.00081298>,
#  <Quantity 0.00081178>,
#  <Quantity 0.00080775>,
#  <Quantity 0.00080663>,
#  <Quantity 0.00080645>,
#  <Quantity 0.0008014>,
#  <Quantity 0.00079926>,
#  <Quantity 0.00079907>,
#  <Quantity 0.00079816>,
#  <Quantity 0.00079768>,
#  <Quantity 0.0007975>,
#  <Quantity 0.00079682>,
#  <Quantity 0.00079435>,
#  <Quantity 0.00079222>,
#  <Quantity 0.00079092>,
#  <Quantity 0.00079037>,
#  <Quantity 0.00078967>,
#  <Quantity 0.00078951>,
#  <Quantity 0.00078916>,
#  <Quantity 0.00078571>,
#  <Quantity 0.00078089>,
#  <Quantity 0.00078088>,
#  <Quantity 0.00078056>,
#  <Quantity 0.00077747>,
#  <Quantity 0.00077683>,
#  <Quantity 0.00077488>,
#  <Quantity 0.00077478>,
#  <Quantity 0.00077232>,
#  <Quantity 0.00077194>,
#  <Quantity 0.00077051>,
#  <Quantity 0.00076947>,
#  <Quantity 0.00076837>,
#  <Quantity 0.00076737>,
#  <Quantity 0.0007652>,
#  <Quantity 0.00076498>,
#  <Quantity 0.00076398>,
#  <Quantity 0.00075889>,
#  <Quantity 0.00075881>,
#  <Quantity 0.00075545>,
#  <Quantity 0.00075505>,
#  <Quantity 0.00075498>,
#  <Quantity 0.0007546>,
#  <Quantity 0.0007527>,
#  <Quantity 0.00074977>,
#  <Quantity 0.0007492>,
#  <Quantity 0.00074859>,
#  <Quantity 0.00074734>,
#  <Quantity 0.00074661>,
#  <Quantity 0.00074527>,
#  <Quantity 0.00074073>,
#  <Quantity 0.00073332>,
#  <Quantity 0.00073186>,
#  <Quantity 0.00073186>,
#  <Quantity 0.00073004>,
#  <Quantity 0.00072851>,
#  <Quantity 0.00072782>,
#  <Quantity 0.00072671>,
#  <Quantity 0.00072592>,
#  <Quantity 0.0007247>,
#  <Quantity 0.00072149>,
#  <Quantity 0.00071979>,
#  <Quantity 0.00071964>,
#  <Quantity 0.00071664>,
#  <Quantity 0.0007163>,
#  <Quantity 0.0007163>,
#  <Quantity 0.00071319>,
#  <Quantity 0.00071267>,
#  <Quantity 0.00071024>,
#  <Quantity 0.00070999>,
#  <Quantity 0.00070876>,
#  <Quantity 0.00070715>,
#  <Quantity 0.00070416>,
#  <Quantity 0.00070066>,
#  <Quantity 0.00069998>,
#  <Quantity 0.00069843>,
#  <Quantity 0.00069749>,
#  <Quantity 0.00069738>,
#  <Quantity 0.00069334>,
#  <Quantity 0.00069183>,
#  <Quantity 0.00068947>,
#  <Quantity 0.00068873>,
#  <Quantity 0.0006833>,
#  <Quantity 0.0006832>,
#  <Quantity 0.00068278>,
#  <Quantity 0.00067938>,
#  <Quantity 0.0006759>,
#  <Quantity 0.00067434>,
#  <Quantity 0.0006711>,
#  <Quantity 0.0006703>,
#  <Quantity 0.00067027>,
#  <Quantity 0.00066838>,
#  <Quantity 0.00066677>,
#  <Quantity 0.00066436>,
#  <Quantity 0.00066395>,
#  <Quantity 0.00066226>,
#  <Quantity 0.00066026>,
#  <Quantity 0.00065599>,
#  <Quantity 0.00065412>,
#  <Quantity 0.00065403>,
#  <Quantity 0.00065392>,
#  <Quantity 0.0006539>,
#  <Quantity 0.00065364>,
#  <Quantity 0.00065292>,
#  <Quantity 0.00064666>,
#  <Quantity 0.00064331>,
#  <Quantity 0.00064253>,
#  <Quantity 0.00064137>,
#  <Quantity 0.00063742>,
#  <Quantity 0.00063589>,
#  <Quantity 0.00063575>,
#  <Quantity 0.00063395>,
#  <Quantity 0.00063277>,
#  <Quantity 0.00062871>,
#  <Quantity 0.00062749>,
#  <Quantity 0.00062735>,
#  <Quantity 0.00062516>,
#  <Quantity 0.00062415>,
#  <Quantity 0.00061909>,
#  <Quantity 0.00061821>,
#  <Quantity 0.00061649>,
#  <Quantity 0.0006137>,
#  <Quantity 0.00061334>,
#  <Quantity 0.000612>,
#  <Quantity 0.00060623>,
#  <Quantity 0.0006054>,
#  <Quantity 0.00060276>,
#  <Quantity 0.00060012>,
#  <Quantity 0.00059921>,
#  <Quantity 0.0005987>,
#  <Quantity 0.00059734>,
#  <Quantity 0.00059561>,
#  <Quantity 0.00059499>,
#  <Quantity 0.00058967>,
#  <Quantity 0.00058947>,
#  <Quantity 0.00058905>,
#  <Quantity 0.00058822>,
#  <Quantity 0.00058813>,
#  <Quantity 0.00058624>,
#  <Quantity 0.00058514>,
#  <Quantity 0.00058482>,
#  <Quantity 0.0005835>,
#  <Quantity 0.00058297>,
#  <Quantity 0.00058272>,
#  <Quantity 0.00058185>,
#  <Quantity 0.00058157>,
#  <Quantity 0.00057923>,
#  <Quantity 0.00057887>,
#  <Quantity 0.00057395>,
#  <Quantity 0.00057291>,
#  <Quantity 0.0005718>,
#  <Quantity 0.00057116>,
#  <Quantity 0.00056939>,
#  <Quantity 0.00056723>,
#  <Quantity 0.00056639>,
#  <Quantity 0.00056569>,
#  <Quantity 0.00056412>,
#  <Quantity 0.00056355>,
#  <Quantity 0.00056331>,
#  <Quantity 0.00056283>,
#  <Quantity 0.00056211>,
#  <Quantity 0.0005601>,
#  <Quantity 0.00055999>,
#  <Quantity 0.00055993>,
#  <Quantity 0.00055966>,
#  <Quantity 0.00055471>,
#  <Quantity 0.00055197>,
#  <Quantity 0.00055185>,
#  <Quantity 0.00055083>,
#  <Quantity 0.00055066>,
#  <Quantity 0.00054654>,
#  <Quantity 0.00054595>,
#  <Quantity 0.0005457>,
#  <Quantity 0.00054503>,
#  <Quantity 0.0005411>,
#  <Quantity 0.00053954>,
#  <Quantity 0.00053923>,
#  <Quantity 0.00053818>,
#  <Quantity 0.00053706>,
#  <Quantity 0.00053686>,
#  <Quantity 0.00053553>,
#  <Quantity 0.00053542>,
#  <Quantity 0.00053507>,
#  <Quantity 0.00053473>,
#  <Quantity 0.00053274>,
#  <Quantity 0.00053267>,
#  <Quantity 0.00053106>,
#  <Quantity 0.00053103>,
#  <Quantity 0.00052879>,
#  <Quantity 0.00052804>,
#  <Quantity 0.00052559>,
#  <Quantity 0.00052389>,
#  <Quantity 0.00052359>,
#  <Quantity 0.00052215>,
#  <Quantity 0.00052157>,
#  <Quantity 0.00052046>,
#  <Quantity 0.00051859>,
#  <Quantity 0.0005183>,
#  <Quantity 0.00051715>,
#  <Quantity 0.00051617>,
#  <Quantity 0.00051485>,
#  <Quantity 0.00051471>,
#  <Quantity 0.0005129>,
#  <Quantity 0.00051193>,
#  <Quantity 0.00051034>,
#  <Quantity 0.00050779>,
#  <Quantity 0.00050766>,
#  <Quantity 0.00050619>,
#  <Quantity 0.00050603>,
#  <Quantity 0.00050602>,
#  <Quantity 0.00050527>,
#  <Quantity 0.00050457>,
#  <Quantity 0.00050406>,
#  <Quantity 0.00050405>,
#  <Quantity 0.0005024>,
#  <Quantity 0.00050089>,
#  <Quantity 0.00050011>,
#  <Quantity 0.00049954>,
#  <Quantity 0.00049933>,
#  <Quantity 0.00049805>,
#  <Quantity 0.00049782>,
#  <Quantity 0.00049763>,
#  <Quantity 0.0004953>,
#  <Quantity 0.00049451>,
#  <Quantity 0.00049429>,
#  <Quantity 0.00049261>,
#  <Quantity 0.00049253>,
#  <Quantity 0.0004924>,
#  <Quantity 0.00049209>,
#  <Quantity 0.00049195>,
#  <Quantity 0.00049121>,
#  <Quantity 0.00049046>,
#  <Quantity 0.00048991>,
#  <Quantity 0.0004872>,
#  <Quantity 0.00048647>,
#  <Quantity 0.00048555>,
#  <Quantity 0.00048514>,
#  <Quantity 0.00048459>,
#  <Quantity 0.00048332>,
#  <Quantity 0.000483>,
#  <Quantity 0.00048076>,
#  <Quantity 0.00048055>,
#  <Quantity 0.0004798>,
#  <Quantity 0.00047956>,
#  <Quantity 0.00047838>,
#  <Quantity 0.00047739>,
#  <Quantity 0.00047738>,
#  <Quantity 0.00047648>,
#  <Quantity 0.00047625>,
#  <Quantity 0.00047564>,
#  <Quantity 0.00047443>,
#  <Quantity 0.00047395>,
#  <Quantity 0.00047285>,
#  <Quantity 0.0004728>,
#  <Quantity 0.00047157>,
#  <Quantity 0.00047048>,
#  <Quantity 0.00046922>,
#  <Quantity 0.00046807>,
#  <Quantity 0.00046735>,
#  <Quantity 0.00046698>,
#  <Quantity 0.00046427>,
#  <Quantity 0.00046403>,
#  <Quantity 0.00046359>,
#  <Quantity 0.0004617>,
#  <Quantity 0.00045743>,
#  <Quantity 0.00045626>,
#  <Quantity 0.00045599>,
#  <Quantity 0.00045505>,
#  <Quantity 0.00045447>,
#  <Quantity 0.00045437>,
#  <Quantity 0.00045436>,
#  <Quantity 0.00045389>,
#  <Quantity 0.00045276>,
#  <Quantity 0.00045264>,
#  <Quantity 0.00045167>,
#  <Quantity 0.00045103>,
#  <Quantity 0.00045055>,
#  <Quantity 0.00044899>,
#  <Quantity 0.00044848>,
#  <Quantity 0.00044789>,
#  <Quantity 0.00044785>,
#  <Quantity 0.0004476>,
#  <Quantity 0.00044753>,
#  <Quantity 0.00044749>,
#  <Quantity 0.00044696>,
#  <Quantity 0.00044629>,
#  <Quantity 0.00044601>,
#  <Quantity 0.00044584>,
#  <Quantity 0.00044565>,
#  <Quantity 0.00044488>,
#  <Quantity 0.00044343>,
#  <Quantity 0.00044293>,
#  <Quantity 0.00044057>,
#  <Quantity 0.00043999>,
#  <Quantity 0.0004399>,
#  <Quantity 0.00043709>,
#  <Quantity 0.00043679>,
#  <Quantity 0.00043478>,
#  <Quantity 0.00043473>,
#  <Quantity 0.00043404>,
#  <Quantity 0.00043394>,
#  <Quantity 0.00043231>,
#  <Quantity 0.00043118>,
#  <Quantity 0.0004307>,
#  <Quantity 0.00042966>,
#  <Quantity 0.00042956>,
#  <Quantity 0.00042945>,
#  <Quantity 0.00042941>,
#  <Quantity 0.00042904>,
#  <Quantity 0.00042745>,
#  <Quantity 0.00042707>,
#  <Quantity 0.00042698>,
#  <Quantity 0.00042608>,
#  <Quantity 0.00042596>,
#  <Quantity 0.00042479>,
#  <Quantity 0.00042359>,
#  <Quantity 0.00042331>,
#  <Quantity 0.00042325>,
#  <Quantity 0.00042143>,
#  <Quantity 0.00041955>,
#  <Quantity 0.00041883>,
#  <Quantity 0.00041803>,
#  <Quantity 0.00041748>,
#  <Quantity 0.00041561>,
#  <Quantity 0.00041531>,
#  <Quantity 0.00041394>,
#  <Quantity 0.00041357>,
#  <Quantity 0.00041332>,
#  <Quantity 0.00041282>,
#  <Quantity 0.0004127>,
#  <Quantity 0.00041134>,
#  <Quantity 0.00041117>,
#  <Quantity 0.00041059>,
#  <Quantity 0.00041057>,
#  <Quantity 0.00041056>,
#  <Quantity 0.00041019>,
#  <Quantity 0.00040941>,
#  <Quantity 0.00040933>,
#  <Quantity 0.00040772>,
#  <Quantity 0.00040734>,
#  <Quantity 0.00040481>,
#  <Quantity 0.00040349>,
#  <Quantity 0.00040302>,
#  <Quantity 0.00040142>,
#  <Quantity 0.00040134>,
#  <Quantity 0.00040076>,
#  <Quantity 0.00040005>,
#  <Quantity 0.00039947>,
#  <Quantity 0.00039908>,
#  <Quantity 0.0003969>,
#  <Quantity 0.00039689>,
#  <Quantity 0.00039505>,
#  <Quantity 0.00039336>,
#  <Quantity 0.00039336>,
#  <Quantity 0.00039231>,
#  <Quantity 0.00039208>,
#  <Quantity 0.00039135>,
#  <Quantity 0.00039127>,
#  <Quantity 0.00038942>,
#  <Quantity 0.0003892>,
#  <Quantity 0.0003888>,
#  <Quantity 0.00038844>,
#  <Quantity 0.0003884>,
#  <Quantity 0.00038827>,
#  <Quantity 0.00038784>,
#  <Quantity 0.00038762>,
#  <Quantity 0.00038723>,
#  <Quantity 0.0003868>,
#  <Quantity 0.00038489>,
#  <Quantity 0.0003848>,
#  <Quantity 0.00038469>,
#  <Quantity 0.0003846>,
#  <Quantity 0.00038338>,
#  <Quantity 0.00038226>,
#  <Quantity 0.00038081>,
#  <Quantity 0.00038067>,
#  <Quantity 0.00037979>,
#  <Quantity 0.00037921>,
#  <Quantity 0.00037854>,
#  <Quantity 0.00037804>,
#  <Quantity 0.000378>,
#  <Quantity 0.00037701>,
#  <Quantity 0.00037656>,
#  <Quantity 0.00037619>,
#  <Quantity 0.00037605>,
#  <Quantity 0.00037578>,
#  <Quantity 0.00037539>,
#  <Quantity 0.0003736>,
#  <Quantity 0.00037244>,
#  <Quantity 0.00037044>,
#  <Quantity 0.00037012>,
#  <Quantity 0.00036997>,
#  <Quantity 0.00036789>,
#  <Quantity 0.00036667>,
#  <Quantity 0.00036552>,
#  <Quantity 0.00036398>,
#  <Quantity 0.00036397>,
#  <Quantity 0.00036334>,
#  <Quantity 0.00036316>,
#  <Quantity 0.00036309>,
#  <Quantity 0.00036155>,
#  <Quantity 0.00036134>,
#  <Quantity 0.00036101>,
#  <Quantity 0.00035927>,
#  <Quantity 0.00035905>,
#  <Quantity 0.00035843>,
#  <Quantity 0.00035821>,
#  <Quantity 0.00035801>,
#  <Quantity 0.0003568>,
#  <Quantity 0.00035612>,
#  <Quantity 0.00035601>,
#  <Quantity 0.00035599>,
#  <Quantity 0.00035394>,
#  <Quantity 0.00035337>,
#  <Quantity 0.00035307>,
#  <Quantity 0.0003523>,
#  <Quantity 0.00035096>,
#  <Quantity 0.00035075>,
#  <Quantity 0.00034966>,
#  <Quantity 0.00034935>,
#  <Quantity 0.0003488>,
#  <Quantity 0.0003486>,
#  <Quantity 0.00034805>,
#  <Quantity 0.00034792>,
#  <Quantity 0.00034773>,
#  <Quantity 0.0003445>,
#  <Quantity 0.00034277>,
#  <Quantity 0.00034147>,
#  <Quantity 0.00034126>,
#  <Quantity 0.00034106>,
#  <Quantity 0.00034086>,
#  <Quantity 0.00033834>,
#  <Quantity 0.00033815>,
#  <Quantity 0.00033622>,
#  <Quantity 0.00033496>,
#  <Quantity 0.00033471>,
#  <Quantity 0.00033433>,
#  <Quantity 0.00033409>,
#  <Quantity 0.00033283>,
#  <Quantity 0.00033271>,
#  <Quantity 0.00033031>,
#  <Quantity 0.00033016>,
#  <Quantity 0.00032951>,
#  <Quantity 0.00032945>,
#  <Quantity 0.000329>,
#  <Quantity 0.00032867>,
#  <Quantity 0.00032799>,
#  <Quantity 0.00032766>,
#  <Quantity 0.00032692>,
#  <Quantity 0.00032688>,
#  <Quantity 0.00032684>,
#  <Quantity 0.00032679>,
#  <Quantity 0.00032569>,
#  <Quantity 0.00032527>,
#  <Quantity 0.00032494>,
#  <Quantity 0.00032479>,
#  <Quantity 0.00032475>,
#  <Quantity 0.00032392>,
#  <Quantity 0.00032142>,
#  <Quantity 0.00031926>,
#  <Quantity 0.00031893>,
#  <Quantity 0.00031815>,
#  <Quantity 0.00031807>,
#  <Quantity 0.00031765>,
#  <Quantity 0.00031757>,
#  <Quantity 0.00031623>,
#  <Quantity 0.00031572>,
#  <Quantity 0.00031498>,
#  <Quantity 0.00031465>,
#  <Quantity 0.00031429>,
#  <Quantity 0.00031429>,
#  <Quantity 0.0003141>,
#  <Quantity 0.00031384>,
#  <Quantity 0.00031335>,
#  <Quantity 0.0003133>,
#  <Quantity 0.00031303>,
#  <Quantity 0.00031255>,
#  <Quantity 0.00031241>,
#  <Quantity 0.00031235>,
#  <Quantity 0.00031188>,
#  <Quantity 0.0003118>,
#  <Quantity 0.0003115>,
#  <Quantity 0.00031135>,
#  <Quantity 0.00030963>,
#  <Quantity 0.0003087>,
#  <Quantity 0.00030754>,
#  <Quantity 0.00030682>,
#  <Quantity 0.00030664>,
#  <Quantity 0.00030653>,
#  <Quantity 0.00030559>,
#  <Quantity 0.00030415>,
#  <Quantity 0.0003034>,
#  <Quantity 0.00030339>,
#  <Quantity 0.00030272>,
#  <Quantity 0.00030153>,
#  <Quantity 0.00030151>,
#  <Quantity 0.00029978>,
#  <Quantity 0.00029905>,
#  <Quantity 0.00029873>,
#  <Quantity 0.0002984>,
#  <Quantity 0.00029807>,
#  <Quantity 0.00029689>,
#  <Quantity 0.00029669>,
#  <Quantity 0.00029535>,
#  <Quantity 0.00029494>,
#  <Quantity 0.00029442>,
#  <Quantity 0.00029303>,
#  <Quantity 0.00029292>,
#  <Quantity 0.00029243>,
#  <Quantity 0.00029188>,
#  <Quantity 0.00029151>,
#  <Quantity 0.00029149>,
#  <Quantity 0.00029076>,
#  <Quantity 0.00029043>,
#  <Quantity 0.00029029>,
#  <Quantity 0.00028966>,
#  <Quantity 0.00028803>,
#  <Quantity 0.00028637>,
#  <Quantity 0.00028612>,
#  <Quantity 0.00028601>,
#  <Quantity 0.00028528>,
#  <Quantity 0.00028426>,
#  <Quantity 0.00028341>,
#  <Quantity 0.00028337>,
#  <Quantity 0.00028176>,
#  <Quantity 0.00028154>,
#  <Quantity 0.0002805>,
#  <Quantity 0.00028043>,
#  <Quantity 0.0002793>,
#  <Quantity 0.00027895>,
#  <Quantity 0.00027888>,
#  <Quantity 0.00027829>,
#  <Quantity 0.00027746>,
#  <Quantity 0.00027712>,
#  <Quantity 0.00027656>,
#  <Quantity 0.00027614>,
#  <Quantity 0.00027583>,
#  <Quantity 0.00027486>,
#  <Quantity 0.00027476>,
#  <Quantity 0.00027472>,
#  <Quantity 0.00027452>,
#  <Quantity 0.00027256>,
#  <Quantity 0.0002725>,
#  <Quantity 0.00027176>,
#  <Quantity 0.00027168>,
#  <Quantity 0.00027075>,
#  <Quantity 0.00027039>,
#  <Quantity 0.00026943>,
#  <Quantity 0.00026898>,
#  <Quantity 0.00026871>,
#  <Quantity 0.00026768>,
#  <Quantity 0.00026663>,
#  <Quantity 0.00026624>,
#  <Quantity 0.00026609>,
#  <Quantity 0.00026565>,
#  <Quantity 0.0002656>,
#  <Quantity 0.00026557>,
#  <Quantity 0.00026537>,
#  <Quantity 0.00026434>,
#  <Quantity 0.0002638>,
#  <Quantity 0.00026372>,
#  <Quantity 0.0002626>,
#  <Quantity 0.0002612>,
#  <Quantity 0.00025909>,
#  <Quantity 0.000259>,
#  <Quantity 0.00025791>,
#  <Quantity 0.0002572>,
#  <Quantity 0.00025705>,
#  <Quantity 0.00025655>,
#  <Quantity 0.00025603>,
#  <Quantity 0.00025569>,
#  <Quantity 0.00025553>,
#  <Quantity 0.00025465>,
#  <Quantity 0.00025446>,
#  <Quantity 0.00025407>,
#  <Quantity 0.00025389>,
#  <Quantity 0.00025378>,
#  <Quantity 0.0002531>,
#  <Quantity 0.00025213>,
#  <Quantity 0.00025209>,
#  <Quantity 0.00025056>,
#  <Quantity 0.00025041>,
#  <Quantity 0.00024923>,
#  <Quantity 0.00024891>,
#  <Quantity 0.00024889>,
#  <Quantity 0.00024884>,
#  <Quantity 0.00024729>,
#  <Quantity 0.0002471>,
#  <Quantity 0.00024679>,
#  <Quantity 0.00024665>,
#  <Quantity 0.00024656>,
#  <Quantity 0.00024447>,
#  <Quantity 0.00024418>,
#  <Quantity 0.00024364>,
#  <Quantity 0.000243>,
#  <Quantity 0.00024072>,
#  <Quantity 0.00023967>,
#  <Quantity 0.00023955>,
#  <Quantity 0.00023944>,
#  <Quantity 0.00023899>,
#  <Quantity 0.00023846>,
#  <Quantity 0.00023549>,
#  <Quantity 0.00023457>,
#  <Quantity 0.0002335>,
#  <Quantity 0.00023335>,
#  <Quantity 0.00023317>,
#  <Quantity 0.00023298>,
#  <Quantity 0.00023282>,
#  <Quantity 0.00023264>,
#  <Quantity 0.00023202>,
#  <Quantity 0.00023184>,
#  <Quantity 0.0002311>,
#  <Quantity 0.00023027>,
#  <Quantity 0.00023005>,
#  <Quantity 0.00022872>,
#  <Quantity 0.00022831>,
#  <Quantity 0.00022825>,
#  <Quantity 0.000228>,
#  <Quantity 0.00022756>,
#  <Quantity 0.00022741>,
#  <Quantity 0.00022733>,
#  <Quantity 0.00022565>,
#  <Quantity 0.0002256>,
#  <Quantity 0.00022546>,
#  <Quantity 0.00022502>,
#  <Quantity 0.00022487>,
#  <Quantity 0.00022468>,
#  <Quantity 0.00022382>,
#  <Quantity 0.00022368>,
#  <Quantity 0.00022092>,
#  ...]

# %%
pg.to_table()
# Out:
# <Table length=1314>
#      frequency              period               power
#        1 / d                  d
#       float64              float64              float64
# -------------------- ------------------- ----------------------
# 0.007605734937526927  131.47973315056902 0.00032688100410016953
# 0.015211469875053854   65.73986657528451 0.00029977935555482383
#  0.02281720481258078  43.826577716856335  0.0002540702215832958
# 0.030422939750107708  32.869933287642255 0.00019743185829534466
# 0.038028674687634635    26.2959466301138 0.00017780723599077457
#  0.04563440962516156  21.913288858428167  0.0002815397750664714
#  0.05324014456268849   18.78281902150986 0.00043989772505940587
# 0.060845879500215416  16.434966643821127  0.0004715726663852829
#  0.06845161443774234  14.608859238952114  0.0003065271176757856
#                  ...                 ...                    ...
#     9.92548409347264 0.10075075337208353  3.992426322745948e-05
#    9.933089828410168 0.10067360884423353  4.664565189322834e-05
#    9.940695563347694 0.10059658236462816  0.0001022461143443082
#    9.948301298285221 0.10051967366251452 0.00013350962189212848
#    9.955907033222749 0.10044288246796715   0.000153693323209648
#    9.963512768160275 0.10036620851188474   0.000172739655017019
#    9.971118503097802 0.10028965152598703 0.00019380528290172493
#    9.978724238035328 0.10021321124281174 0.00022368361537492392
#    9.986329972972856 0.10013688739571135  0.0002687123870715104
#    9.993935707910383 0.10006067971885008 0.00031807024955569766

# %%
df_freq = pd.DataFrame(pg.frequency, columns=['Freq'])
df_power = pd.DataFrame(pg.power, columns=['Power'])
table = pd.concat([df_freq, df_power], axis=1)

table
# Out:
#           Freq     Power
# 0     0.007606  0.000327
# 1     0.015211  0.000300
# 2     0.022817  0.000254
# 3     0.030423  0.000197
# 4     0.038029  0.000178
# ...        ...       ...
# 1309  9.963513  0.000173
# 1310  9.971119  0.000194
# 1311  9.978724  0.000224
# 1312  9.986330  0.000269
# 1313  9.993936  0.000318
#
# [1314 rows x 2 columns]

# %%
sorted(table.Power, reverse=True)[0]
# Out:
# 0.06540981279469786

# %%
for i in range(len(table)):
    if table.Power[i] == sorted(table.Power, reverse=True)[0]:
        print(i, table.Freq[i])
# Out:
# 457 3.483426601387333

# %%
power_list = []
freq_list = []

for i in range(10):
    for j in range(len(table)):
        if table.Power[j] == sorted(table.Power, reverse=True)[i]:
            power_list.append(sorted(table.Power, reverse=True)[i])
            freq_list.append(table.Freq[j])

main_freq = pd.DataFrame(freq_list, columns=['Freq'])
main_power = pd.DataFrame(power_list, columns=['Power'])
main_table = pd.concat([main_freq, main_power], axis=1)

main_table
# Out:
#        Freq     Power
# 0  3.483427  0.065410
# 1  3.491032  0.063944
# 2  3.475821  0.057513
# 3  3.498638  0.053498
# 4  3.468215  0.041994
# 5  3.506244  0.036402
# 6  3.430186  0.023389
# 7  3.536667  0.022622
# 8  3.544272  0.022551
# 9  3.460609  0.022390
